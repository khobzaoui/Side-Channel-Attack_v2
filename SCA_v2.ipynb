# %% [markdown]
# <a href="https://colab.research.google.com/github/khobzaoui/Side-Channel-Attack_v2/blob/main/SCA_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
